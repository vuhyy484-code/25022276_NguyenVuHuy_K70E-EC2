# %%
#câu 1
a, b = map(float, input().split())
c = (a+b)*2
s = a*b
print(s, c)
# Out:
# 16.0 15.0

# %%
#câu 2
a = float(input())
s = a*3.14
c = a*2*3.14
print(s, c)

# %%
#câu 3
from math import *
a, b, c =map(float, input().split())
d = a + b + c
p = d/2
s = sqrt(p*(p - a)* (p-b)*(p-c))
if a + b < c or b + c < a or a + c < b:
    print('Khong la ba canh cua mot tam giac')
elif (a == b or b == c or c == a) and (a !=0 and b != 0 and c!= 0 ) and not (a==b==c):
    print('Tam giac can') 
    print(s, c)
elif (a == b == c) and a!=0:
    print('Tam giac deu')
    print(s, d)
else:
    print('Tam giac thuong')
    print(s, d)
# Out:
# Tam giac thuong
# 26.832815729997478 24.0

# %%
#câu 4:
a, b = map(float, input().split())
if a != 0:
    x = -b/a
    print(x)
elif a == 0 and b != 0:
    print('Vô nghiệm')
elif a == 0 and b == 0:
    print('Vô số nghiệm')
# Out:
# -0.05555555555555555

# %%
#câu 5:
from math import *
a, b, c = map(float, input().split())
if a == 0 :
    if b == 0:
        if c == 0:
            print('Vô số nghiệm')
        else:
            print('Vô nghiệm')
    else:
        x = -c/b
        print(x)
else: #tính delta
    delta = b**2 - 4*a*c
    if delta < 0:
        print('Phương trình vô nghiệm')
    elif delta == 0:
        x = -b/(2*a)
        print(f'Phương trình có nghiệm kép = {x}')
    elif delta > 0:
        x1 = (-b + delta*0.5)/2*a
        x2 = (-b - delta*0.5)/2*a
        print(f'Phương trình có hai nghiệm phân biệt là: x1 = {x1}, x2 = {x2}')
# Out:
# Phương trình có hai nghiệm phân biệt là: x1 = 48.0, x2 = -88.0

# %%
#câu 6:
a, b ,c ,d = map(float, input().split())
print(max(a, b ,c ,d))
# Out:
# 34.0

# %%
#câu 7:
a, b, c, d = map(float, input().split())
print(min(a,b,c,d))
# Out:
# 3.0

# %%
#câu 8:
a, b, c, d, m, n = map(float, input().split())
# tính các định thức (phương pháp cramer)
D = a*d - b*c
Dx = m*d - b*n
Dy = m*c - a*n
if D != 0:
    x = Dx/d
    y=Dy/D
    print(f'hệ phương trình có nghiệm là: x = {x}, y = {y}')
else:
    if Dx == 0 and Dy == 0:
        print('hệ phương trình có vô số nghiệm')
    else:
        print('hệ phương trình vô nghiệm')
# Out:
# hệ phương trình có nghiệm là: x = 1.6734693877551021, y = -0.611764705882353

# %%
#câu 9:
x = int(input())
a = x/3600
b = x/60
print(f'số giờ là:{a}, số phút là:{b}, số giây là:{x}')
# Out:
# số giờ là:0.065, số phút là:3.9, số giây là:234

# %%
#câu 10:
from math import *
a, b = map(float, input('Nhập tọa độ của tâm tròn').split())
r = float(input('Nhập bán kính'))
x,y = map(float, input('Nhập tọa độ điểm').split())
c = x-a
d = y - b
if (sqrt(c**2 + d**2)) <= r:
    print(' điểm A thuộc đường tròn')
else:
    print('điểm A không thuộc đường tròn')
# Out:
#  điểm A thuộc đường tròn

# %%
x, y = map(float, input().split())
print(x**y)
# Out:
# 729.0
